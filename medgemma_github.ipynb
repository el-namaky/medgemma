# %% [markdown]
# # 🏥 تشغيل مشروع Med-Gemma على Google Colab (عبر GitHub)
#
# هذا الدفتر (Notebook) يساعدك على تشغيل نظام **Gemma-Health Sentinel** باستخدام موارد Google Colab السحابية (GPU المجانية) وسحب الكود مباشرة من GitHub.
#
# ### الخطوات:
# 1. تأكد من تفعيل GPU من قائمة: `Runtime` -> `Change runtime type` -> `T4 GPU`.
# 2. ضع رابط المستودع الخاص بك (Repository URL) في الخلية القادمة.
# 3. نفذ الخلايا التالية بالترتيب.

# %% [markdown]
# ## 1. استنساخ المستودع (Clone Repository)
# ضع رابط المستودع الخاص بك هنا. إذا كان المستودع خاصًا (Private)، ستحتاج لاستخدام Personal Access Token في الرابط:
# `https://<YOUR_TOKEN>@github.com/username/repo_name.git`

# %%
# 🔴 استبدل الرابط التالي برابط مستودعك
GITHUB_REPO_URL = "https://github.com/el-namaky/medgemma.git"

# اسم المجلد الذي سيتم إنشاؤه (عادةً نفس اسم المستودع)
REPO_NAME = "medgemma"

import os
if os.path.exists(REPO_NAME):
    print(f"⚠️ المجلد {REPO_NAME} موجود بالفعل. سيتم حذف القديم وسحب الجديد.")
    # !rm -rf {REPO_NAME}

print(f"🔄 جاري سحب المشروع من: {GITHUB_REPO_URL}...")
# !git clone {GITHUB_REPO_URL}

if os.path.exists(REPO_NAME):
    os.chdir(REPO_NAME)
    print(f"✅ تم الانتقال إلى: {os.getcwd()}")
else:
    print("❌ حدث خطأ أثناء سحب المستودع. تأكد من الرابط.")
# Out:
# 🔄 جاري سحب المشروع من: https://github.com/el-namaky/medgemma.git...
# Cloning into 'medgemma'...
# remote: Enumerating objects: 85, done.
# remote: Counting objects: 100% (85/85), done.
# remote: Compressing objects: 100% (70/70), done.
# remote: Total 85 (delta 14), reused 81 (delta 10), pack-reused 0 (from 0)
# Receiving objects: 100% (85/85), 180.27 KiB | 1.46 MiB/s, done.
# Resolving deltas: 100% (14/14), done.
# ✅ تم الانتقال إلى: /content/medgemma

# %% [markdown]
# ## 2. تثبيت المكتبات المطلوبة
# قد يستغرق هذا بضع دقائق.

# %%
# !pip install -r requirements.txt
# !pip install gradio transformers accelerate bitsandbytes
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 18.5 MB/s eta 0:00:00
# ...

# %%
# !git pull
# Out:
# Already up to date.

# %% [markdown]
# ## 3. تسجيل الدخول بـ Hugging Face Token
# لتحميل موديل `google/medgemma-4b-it` (أو أي موديل Gated)، تحتاج لـ Access Token.
# 1. اذهب إلى [Hugging Face Settings](https://huggingface.co/settings/tokens).
# 2. انسخ التوكن (Read permission تكفي).
# 3. ألصقه في الخانة التي ستظهر.

# %%
from huggingface_hub import login
login()

# %% [markdown]
# ## 4. تشغيل التطبيق
# سيقوم هذا الأمر بتشغيل التطبيق وإنشاء رابط عام (Public Link) ينتهي بـ `gradio.live`.
# اضغط على الرابط Public URL لفتح التطبيق.

# %%
# تفعيل المتغيرات البيئية لاستخدام GPU الحقيقية وتفعيل المشاركة
import os
os.environ["MEDGEMMA_MOCK"] = "false"
os.environ["GRADIO_SHARE"] = "true"

# تشغيل التطبيق
# !python app.py
# Out:
# ...
# 🏥 Gemma-Health Sentinel — MVP
#    نظام الطوارئ الذكي بالذكاء الاصطناعي
# ...
#
# 📦 Step 1: Initializing database...
# ✅ Database initialized successfully at: /content/medgemma/db/hospital.db
# ✅ Seed data inserted successfully — 5 patients + contraindications table
#
# 🧠 Step 2: Loading MedGemma...
# 🧠 Loading google/medgemma-4b-it...
# ⚠️ Failed to load MedGemma: You are trying to access a gated repo.
# Make sure to have access to it at https://huggingface.co/google/medgemma-4b-it.
# 403 Client Error. (Request ID: Root=1-699392d3-60e757ad466940fd206dd016;ba489afd-f786-409d-a953-3a8e9b311d1b)
#
# Cannot access gated repo for url https://huggingface.co/google/medgemma-4b-it/resolve/main/config.json.
# Access to model google/medgemma-4b-it is restricted and you are not in the authorized list. Visit https://huggingface.co/google/medgemma-4b-it to ask for access.
# 🧪 Falling back to MOCK mode
#
# 🎨 Step 3: Building Gradio interface...
# ...
